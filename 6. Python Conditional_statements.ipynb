# %% [markdown]
# # Statements
# set of instructions/code used to perform certain task.

# %% [markdown]
# # Types of statements
# * simple statements
# * compound statements

# %% [markdown]
# # Simple statements
# A simple statement consists of a single line of code that performs an action. It does not contain nested blocks or multiple instructions.

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# # compound statements
# A compound statement contains multiple instructions, often grouped into blocks, and can span multiple lines. These statements often include control flow structures like conditionals, loops, or functions.

# %% [markdown]
# # conditional statement
# A conditional statement allows a program to make decisions based on whether a condition is True or False. In Python, the if, elif, and else keywords are used to define conditional statements.

# %%
# Whether 10 is greater than 5 or not
# comparison operators
10>5
# Out:
# True

# %% [markdown]
# # if
# Used to check condition and make decisions based on whether condition is true or false
#
#
#
# ```
# if condition:
#   statements(decisions)
# ```

# %%
# first check whether 10 >5 if its true print "Yes 10  is greater than 5"
if 10<5:# True
          print("Yes , 10 is greater than 5")
print("hello")
print("hello")
# Out:
# hello
# hello

# %% [markdown]
# 1. **Condition:** Use the if keyword followed by the condition 10 > 5.
# 2. **True Block:** If the condition is True, execute the code inside the block.
# 3. **Indentation:** Indent the code to indicate it belongs to the conditional block.
# 4. **Output:** Print the result if the condition evaluates to True.

# %% [markdown]
# # Indentation
# Indentation
# In Python, indentation is used to determine the grouping of code blocks. It is a way of visually indicating which statements are part of a particular code block, such as a function, loop, or conditional statement.
#
# Indentation is done using spaces or tabs, but it is important to be consistent in the style used throughout the code. Typically, four spaces are used for each level of indentation.

# %%
''' define input function to input an integer(500) and then verify
whether that number is greater than 100 or not '''
num = int(input("Enter the no: ")) # takes interger input from user
if num>100:# 500>100:True
  print("yes number is greater than 100")
# Out:
# Enter the no: 101
# yes number is greater than 100

# %%
''' create an input function to input age , verify  whether
Ridaa is eligible to vote or not , if Ridaa's age is 30'''
age = int(input("Enter the age: "))
if age>=18:
  print("Your age is greater than 18 years")
  print(f"You can vote since your age is {age}")
print("Thanks")
# Out:
# Enter the age: 25
# Your age is greater than 18 years
# You can vote since your age is 25
# Thanks

# %%
''' create an input function to input integer (30)
 verify whether integer 30 is positive or not '''
num = int(input())
if num >= 0:
  print(f"{num} is positive")
# Out:
# -10

# %%
num = int(input())
if num > 0:
  print(f"{num} is positive")
print("done")
# Out:
# -5

# %% [markdown]
# # What happens if condition fails?

# %%
num = int(input())
if num >= 0:#False
  print(f"{num} is positive")
print("done")
# Out:
# -10
# done

# %% [markdown]
# # else
# The else condition in Python provides an alternative block of code/decision that executes when the if condition evaluates to False.
#
#
# if-else
#
# ```
# if condition:
#   statements(when if condition is True)
# else:
#   statements(when if condition is False)
# ```

# %%
num = int(input("Enter the no."))
if num >=0:#False
  print(f"{num} is positive")
else:
  print(f"{num} is negative")
# Out:
# Enter the no.-100
# -100 is negative

# %%
''' create an input function to input age , verify  whether
Ridaa is eligible to vote or not , if Ridaa's age is 30'''
age =int(input())
if age>=18:
  print(f"Ridaa is eligible to vote since her age is {age}")
else:
  print(f"Ridaa is not eligible to vote since her age is {age}")
# Out:
# 14
# Ridaa is not eligible to vote since her age is 14

# %%
''' Verify whether 20 is even or not
create input function to take integers , print even if True else print odd'''
# num%2==0 conditon for even number
# num%2==1 conditon for odd number
## input =20 ,output : 20  even
## input 17 , output : 17 is odd
num =int(input())
if num%2==0:
  print(f"{num} is even")
else:
  print(f"{num} is odd")
# Out:
# 45
# 45 is odd

# %%
num =int(input())
if num%2==1:
  print(f"{num} is odd")
else:
  print(f"{num} is even")
# Out:
# 16
# 16 is even

# %%
# check whether a number is divisible by 3 ?
num =int(input())
if num%3==0:
  print(f"{num} is multiple or divisible by 3")
else:
  print(f"{num} is not multiple or divisible by 3")
# Out:
# 16
# 16 is not multiple or divisible by 3

# %%
# check whether a number is divisible by both 3 and 7
num =int(input())
if (num%3==0) and (num%7==0):
  print(f"{num} is divisible by both 3 and 7")
else:
  print(f"{num} is not divisible by both 3 and 7")
# Out:
# 15
# 15 is not divisible by both 3 and 7

# %%
# check whether a number is divisible by either 3 or 7
num =int(input())
if (num%3==0) or (num%7==0):
  print(f"{num} is divisible by either 3 or 7")
else:
  print(f"{num} is not divisible by both 3 or 7")
# Out:
# 15
# 15 is divisible by either 3 or 7

# %%
''' You're a gardener and need to check if a plant needs watering.
If the soil moisture level is below 50%, print "Water the plant!",
otherwise, print "The plant doesn't need watering" '''
# moisturelevel=40 , moisturelevel=70
moisture_level=int(input("Enter the moisture level: "))
if moisture_level>50:
  print("The plant doesn't need watering")
else:
  print("Water the plant")
# Out:
# Enter the moisture level: 20
# Water the plant

# %%
# moisturelevel=40 , moisturelevel=70
moisture_level=int(input())
if moisture_level>50:
  print("The plant doesn't need watering")
else:
  print("Water the plant")
# Out:
# 70
# The plant doesn't need watering

# %%
# x[::-1] to reverse the data
x = "Abhishek"
print(x[::-1])
# Out:
# kehsihbA

# %%
''' Write a program to check given string is palindrome or not'''
# Palindrome: reverse of word is exactly same as original word
# Eg: mom ,dad,madam,racecar,level , malayalam , eye
# Input : mom , Input: sql
word = input("Enter the word: ")
if word == word[::-1]:
  print(f"Yes, it the {word} is a palindrome")
else:
  print(f"{word} is not palindrome")
# Out:
# Enter the word: Racecar
# Racecar is not palindrome

# %%
word = input()
if word == word[::-1]:
  print(f"{word} is palindrome")
else:
  print(f"{word} is not palindrome")
# Out:
# ABhi
# ABhi is not palindrome

# %%
word = input("Enter the word: ")
if word.lower() == word.lower()[::-1]:
  print(f"{word} is palindrome")
else:
  print(f"{word} is not palindrome")
# Out:
# Enter the word: LevEl
# LevEl is palindrome

# %%
# # check whether given character is  vowel or consonant
# vowels : aeiouAEIOU
char = input()
if char in 'aeiouAEIOU':
  print(f"{char} is vowel")
else:
  print(f"{char} is consonant")
# Out:
# d
# d is consonant

# %%
char = input()
if char in 'aeiouAEIOU':
  print(f"{char} is vowel")
else:
  print(f"{char} is consonant")
# Out:
# A
# A is vowel

# %%
#colors = ["Blue","green","orange","yellow"]
# write a program to verify whether green is in colors are not
# take list and element from users
# eval(input()) is used to take list /tuple/set/dict from users
# input() usedt to take string from users
colors = ["Blue","green","orange","yellow"]
element = input()
if element in colors:
  print(f"{element} present in colors:->{colors}")
else:
  print(f"{element} not present in colors:->{colors}")
# Out:
# blue
# blue not present in colors:->['Blue', 'green', 'orange', 'yellow']

# %%
#colors = ["Blue","green","orange","yellow"]
# write a program to verify whether green is in colors are not
# take list and element from users
# eval(input()) is used to take list /tuple/set/dict from users
# input() used to take string from users
colors = eval(input())
print(type(colors))
element = input()
if element in colors:
  print(f"{element} present in {colors}")
else:
  print(f"{element} not present in {colors}")
# Out:
# ["Blue","green","orange","yellow"]
# <class 'list'>
# green
# green present in ['Blue', 'green', 'orange', 'yellow']

# %%
colors = eval(input())
element = input()
if element in colors:
  print(f"{element} present in {colors}")
else:
  print(f"{element} not present in {colors}")
# Out:
# ["Blue","green","orange","yellow"]
# pink
# pink not present in ['Blue', 'green', 'orange', 'yellow']

# %% [markdown]
# # if-elif-else
# Elif is used to check multiple conditions.

# %% [markdown]
# ```
# if condition:
#   statements(when if condition is True)
# elif condition:
#   statements(when elif condition is TRue)
# elif condition:
#   statements(When second elif condition is True)
# else:
#   statements(when above conditions are False)
# ```

# %%
''' Write a program to check whether given number is positive , negative or zero'''
num = int(input())
if num>0: # True
  print(f"{num} is positive")
elif num==0:
  print(f"{num} is zero")
else: # handling negative case
  print(f"{num} is negative")
# Out:
# 0
# 0 is zero

# %%
num = int(input())
if num>0:# Fails
  print(f"{num} is positive")
elif num<0:#True
  print(f"{num} is negative")
else: # handling zero case
  print(f"{num} is zero")
# Out:
# -100
# -100 is negative

# %%
num = int(input())
if num>0:# Fails
  print(f"{num} is positive")
elif num<0:#fails
  print(f"{num} is negative")
else:# True
  print(f"{num} is zero")
# Out:
# 0
# 0 is zero

# %%
age = int(input())
if 18<=age<=100:
  print("adult")
elif 13<=age<18:
  print("Teenager")
elif 0<=age<13:
  print("child")
else:
  print("Invalid")
# Out:
# 15
# Teenager

# %%
# age >= 18 : adult , 18>=age>=13 : You are teenager, else: You are a child
# define input for age
# age>=18 ---> adult
# 18>age >=13 ---> teenager
# age <13 --> child
# else : Invalid
age = int(input())
if  13<=age<=18:
  print("teenager")
elif 18<age<=100:
  print("adult")
elif 0<=age<13:
  print("child")
else:
  print("Invalid")
# Input 40 : adult
# Input 17 : Teenager
# Input 10 : child
# Input 3000 : Invalid
# Input -30 : Invalid
# Out:
# -5
# Invalid

# %%
# Pratice : Grade Book
# marks as input , Grade as an Output
# Condition
# >= 80 and <=100 : Grade A
# >60 - < 80 : Grade B
# > 30 - <=60 : Grade C
# <=30 and >0: Fail
# else: Marks is not valid
marks = int(input())
if (80<=marks) and (marks<=100):
  print("Grade A")
elif 60<=marks<80:
  print("Grade B")
elif 30<=marks<60:
  print("Grade C")
elif 0<=marks<30:
  print("fail")
else:
  print("Invalid")
  # 90:Grade A
  # 70:Grade B
  # 40:Grade C
  #10:Fail
  # Invalid
# Out:
# 85
# Grade A

# %%
marks=int(input())
if marks >=80 and marks <= 100:
  print("Grade A")
elif marks >60 and marks <80:
  print("Grade B")
elif marks>30 and marks <=60:
  print("Grade C")
elif marks > 0 and marks <=30:
  print("Fail")
else:
  print("Marks is invalid")

# %%
marks=90
if 80>=marks<100:
  print("hello")

# %%
# Practice :
# Determine the season based on the month:

# Condition :
# 3 <= month <= 5 : Spring
# 6 <= month <= 8 : Summer
# 9 <= month <= 11 : Autumn
# Rest : Winter
# <1 , > 12 : Invalid
month =int(input())
if month>=12 or  month<=1:
  print("Invalid")
elif month>=3 and month<=5: # 3<=month<=5
  print("Spring")
elif month>=6 and month<=8:
  print("Summer")
elif month>=9 and month<=11:
  print("Autumn")
else:
  print("Winter")

# %%
# Determine the discount based on the purchase amount:
# purchase_amount >= 1000 : 10 % discount
# purchase_amount >= 500 and < 1000 : 5 % discount
# Otherwise 0% discount

purchase_amount = float(input())
if purchase_amount>=1000:
  discount = purchase_amount*0.1
  print(f"You are getting 10% discount and your discount is {discount}")
elif purchase_amount>=500 and purchase_amount<1000:
  discount = purchase_amount*0.05
  print(f"You are getting 5% discount and your discount is {discount}")
else:
  print("You are getting 0% discount and your discount is zero only")
# Out:
# 999
# You are getting 5% discount and your discount is 49.95

# %% [markdown]
# # Nested if statements
# If statement within another if statements
#
#
#
# ```
# if condition:
#   statements
#   if condition:
#     statements
#   else:
#     statements
# else:
#  statements
#
# ```

# %%
'''
write a program
check whether number is positive
If positive , print positive and then check whether number even or odd
else print negative  or zero
'''
num =int(input())
if num>0:#outer
  print(f"{num} is positive")
  if num%2==0:# inner
    print(f"{num} is even")
  else:
    print(f"{num} is odd")
elif num<0:
  print(f"{num} is negative")
else:
  print(f"{num} is zero")
# Out:
# 100
# 100 is positive
# 100 is even

# %%
num = int(input("Enter a number: "))

if num > 0:
    if num%2 == 0:
        print(f"{num} is positive and even")
    else:
        print(f"{num} is positive and odd")
else:
    print(f"{num} is either negative or zero")
# Out:
# Enter a number: 45
# 45 is positive and odd

# %%
words = ["python","wow","sql","level"]
# check "wow" is in words or not , if it is present the check
# whether "wow" is palindrome or not
# If word is not present , print not present
lst = ["python","wow","sql","level"]
word = input()
if word in lst:
  print(f"{word} is in lst")
  if word==word[::-1]:
    print(f"{word} is palindrome")
  else:
    print(f"{word} is not palindrome")
else:
  print(f"{word} is not in lst")
# Out:
# abhi
# abhi is not in lst

# %%
lst = ["python","wow","sql","level"]
word ="sql"
if word in lst:
  print(f"{word} is in lst")
  if word==word[::-1]:
    print(f"{word} is palindrome")
  else:
    print(f"{word} is not palindrome")
else:
  print(f"{word} is not in lst")
# Out:
# sql is in lst
# sql is not palindrome

# %%
lst = ["python","wow","sql","level"]
word ="Jeevitha"
if word in lst:
  print(f"{word} is in lst")
  if word==word[::-1]:
    print(f"{word} is palindrome")
  else:
    print(f"{word} is not palindrome")
else:
  print(f"{word} is not in lst")
# Out:
# Jeevitha is not in lst

# %%
# If element present just print element present
# If elemnet not present check is it palindrome or not
lst = ["python","wow","sql","level"]
word ="racecar"
if word in lst:
  print(f"{word} is in lst")
else:
  print(f"{word} is not in lst")
  if word==word[::-1]:
    print(f"{word} isadfad palindrome")
  else:
    print(f"{word} is not dafsdfasdpalindrome")
# Out:
# racecar is not in lst
# racecar isadfad palindrome

# %%
lst = ["python","wow","sql","level"]
word ="Abhi"
if word in lst:
  print(f"{word} is in lst")
  if word==word[::-1]:
    print(f"{word} is palindrome")
  else:
    print(f"{word} is not palindrome")
else:
  print(f"{word} is not in lst")
  if word==word[::-1]:
      print(f"{word} is palindrome")
  elif word == "Abhi":
      print(f"{word} is Data Scientist")
  else:
      print(f"{word} is not palindrome")
# Out:
# Abhi is not in lst
# Abhi is Data Scientist

# %%
lst = ["python","wow","sql","level"]
word ="Abhi"
if word in lst:
  print(f"{word} is in lst")
  if word==word[::-1]:
    print(f"{word} is palindrome")
  else:
    print(f"{word} is not palindrome")
else:
  if word==word[::-1]:
    print(f"{word} is palindrome")
  elif word == "Abhi":
    print(f"{word} is Data Scientist")
  else:
    print(f"{word} is not palindrome")
# Out:
# Abhi is Data Scientist
