# %% [markdown]
# ## **Session Flow:**
#
# ###**👨🏻‍🎓 Learning Objective:**
#
# * Introduction
# * Theme
# * Primary Goals
#
# 🎯Introduction to Sampling
#
# - Definition of Sampling 📚
# - Importance of Sampling in Statistics 📊🌐
#
# 🎲Probability Sampling
#
# - Introduction to Probability Sampling 📊
# - Random Sample: Definition and Importance 🎯📝
# - Random Sample Notation: Notations for Random Samples 📄🎫
# - Central Limit Theorem📉📊
# - Normal Approximations Using Central Limit Theorem (CLT)📉📊
#
# ❌🎲Non-Probability Sampling
#
# - Introduction to Non-Probability Sampling ❌📊
# - Types of Non-Probability Sampling:
#   - Judgment or Purposive or Deliberate Sampling: Definition and Examples 🎯🎯
#   - Convenience Sampling: Definition and Examples 🎫📊
#   - Quota Sampling: Definition and Examples 📋📊
#   - Snowball Sampling: Definition and Examples ☃️🎯
#
# 📝📊Sampling Bias and Estimation
#
# - Introduction to Sampling Bias 🚫📊
# - Definition of a Statistic 📊🔍
# - The Sample Mean: Calculation and Significance 📊📈
# - The Sample Variance: Calculation and Interpretation 📊📉
# - The t-Result: Understanding t-Values and t-Distribution 📊📊
# - The F-Result: Introduction to F-Values and F-Distribution 📊📈
# - Point Estimation: Introduction and Examples 📊🎯
#
# 📐📊Sample Size Determination and Sum of Independent Random Variables
#
# - Introduction to Sample Size Determination 📏📊
# - Sum of Independent Random Variables:
#   - Expected Value (Mean) of the Sum 📊🔢
# Variance of the Sum 📊📉
#   - Using Sum of Independent Random Variables in Sample Size Determination 📊🧮
#   - Importance of Adequate Sample Size 📊✅
# - Activity
#
# 📝 Summary
#
# * What did we learn?
# * Shortcomings & Challenges
# * Best Practices & Tips
#
# 🔗 Enhance your Knowledge
#
# * Mnemonic
# * Additional Resources
#
# 🔍 Try it Yourself
#
# * Activities
# * Social Engagement

# %% [markdown]
# ##**👨🏻‍🎓 Learning Objective: "📈 Sampling & Statistical Inference🔢"**
#
# ###**Introduction**
#
# Welcome to the fascinating world of "**Statistical Inference**"! 📈🔢 In this learning journey, we will explore the essential concepts and techniques of statistics, empowering you to analyze and draw meaningful inferences from data. Statistics is a powerful tool that helps us make sense of the vast amount of information around us. Whether you're interested in scientific research, business analytics, or simply want to enhance your analytical skills, understanding statistics is crucial. 🧠💡 By mastering random sampling, statistical distributions, and estimation methods, you'll become a more critical thinker and a confident problem solver, ready to tackle real-world challenges. So, let's embark on this statistical adventure together and uncover the hidden insights within data, contributing to a more data-driven and informed world! 🚀🌟
#
# ###**Theme: 📊 Understanding the World through Statistical Inference. 🌍**
#
# In today's data-driven world, the ability to harness the power of statistics and estimation is paramount. 📈🔢
# By delving into this topic, you will acquire the tools to make sense of complex data, draw reliable conclusions, and gain valuable insights from information all around us. Whether you aspire to be a data scientist, researcher, or decision-maker in any field, statistics will be your guiding light in navigating through uncertainties. 🧠💡 Understanding statistical concepts like random sampling, distributions, and estimation methods will transform you into a critical thinker and problem solver, capable of interpreting real-world data and making evidence-based decisions. This theme invites you to explore the wonders of data analysis and inference, empowering you to contribute to a more informed and data-driven world. 🚀🌟
#
# ###**Primary Goals:**
# * 🧠💡 Equip learners with fundamental concepts and tools of statistics.
# * 📊 Understand random sampling, statistical distributions, and estimation techniques.
# * 🤔 Become critical thinkers and confident problem solvers through data analysis.
# * 🔍 Explore real-world data, unlock valuable insights, and make evidence-based decisions.
# * 🚀🌟 Contribute to shaping a more data-driven and informed world.

# %% [markdown]
# #**📖 Learning Material 📖**

# %% [markdown]
# ## **Introduction to Sampling**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >> Sampling refers to the process of selecting a subset, known as a sample, from a larger group, known as a population. The sample is carefully chosen to be representative of the population's characteristics, allowing researchers to draw meaningful conclusions about the entire population based on the analysis of the sample data. Sampling involves techniques that aim to minimize bias and ensure the sample accurately reflects the diversity and variability present in the population.

# %% [markdown]
# ### **Importance of Sampling in Statistics**

# %% [markdown]
# 🕒⚖️ **Time and Cost Efficiency:** Collecting data from an entire population can be impractical, time-consuming, and expensive. Sampling allows researchers to obtain accurate information using a smaller budget and within a reasonable timeframe.
#
# 🔍📊 **Inference:** Statistical analysis of a well-selected sample can provide insights and draw conclusions about the entire population. This is the basis of inferential statistics, which generalize findings from the sample to the larger population.
#
# 🤝🔬 **Feasibility:** In cases where the population is too large or inaccessible, sampling provides a feasible way to study and understand the population's characteristics.
#
# 💼📝 **Reduced Data Collection Effort:** Instead of gathering data from all individuals, researchers can focus on collecting data from a smaller group, making data collection more manageable.
#
# 🔍🛡️ **Risk Reduction:** Sampling allows researchers to evaluate hypotheses and test new ideas on a smaller scale before implementing them on the entire population, reducing potential risks and errors.
#
# 🔒🌐 **Ethics:** In cases where it is not feasible or ethical to collect data from every individual, sampling provides a way to gather relevant information without invading privacy or causing harm.

# %% [markdown]
# ## **Probability Sampling**

# %% [markdown]
# - Probabilty sampling involves the selection of elements from the population using random in which each element of the population has an equal and independent chance of being chosen.
# - To put it simple, It is a sampling technique wherein the samples are gathered in a process that gives all the individuals in the population equal chances of being selected.
# - Imagine you have a big bag of candies, and you want to know what flavors are inside without eating all of them. Probability sampling is like reaching into the bag and picking out candies in a way that gives every candy an equal chance to be chosen. This method helps you get a good idea of what flavors are in the bag without having to check every single candy.
# - It is also called random sampling.

# %% [markdown]
# ### **Random Sample**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 🔢 A set of items selected from a parent population is a random sample if:
#
# 🎲 the probability that any item in the population is included in the sample is proportional to its frequency in the parent population, and
#
# 🤝 the inclusion/exclusion of any item in the sample operates independently of the inclusion/exclusion of any other item.

# %% [markdown]
# ### **Random Sample Notation**

# %% [markdown]
# 🔢 A random sample is made up of (iid) random variables and so they are denoted by capital X’s.
#
# 📊 We will use the shorthand notation X to denote a random sample, that is, X = (X1, X2, ..., Xn).
#
# 📈 An observed sample will be denoted by $x = (x_1, x_2, \ldots, x_n)$.
#
# 🔑 The population distribution will be specified by a density (or probability function) denoted by f(x;θ), where θ denotes the parameter(s) of the distribution such as mean (denoted by μ) and variance (denoted by $\sigma^2$).

# %% [markdown]
# ### **Central Limit Theorem**
# 🔢📈🧮📉🎲
#
# The central limit theorem is one of the most important theorems in probability theory and statistics. It states that, under certain conditions, the sum of a large number of independent and identically distributed random variables will be approximately normally distributed, regardless of the underlying distribution of the individual random variables. Here are some important points about the central limit theorem:
#
# **1. Definition:**
#
# The central limit theorem (CLT) states that the distribution of the sample mean of a large number of independent and identically distributed random variables approaches a normal distribution, regardless of the underlying distribution of the individual random variables.
#
# **2. Conditions:**
#
# The central limit theorem holds under certain conditions, including that the sample size is sufficiently large, the observations are independent, and the population distribution has a finite variance.
#
# **3. Importance:**
#
# The central limit theorem is important because it allows us to make inferences about the population mean based on a sample mean, even when the underlying distribution is unknown or non-normal.
#
# **4. Applications:**
#
# The central limit theorem has many applications in statistics and data analysis, including hypothesis testing, confidence intervals, and regression analysis.
#
# **5. Example:**
#
# Here's an example of how the central limit theorem works in practice. Suppose we want to know the average height of all students in a school, but it's not practical to measure the height of every student. Instead, we can take a random sample of students and calculate the sample mean. By the central limit theorem, as the sample size increases, the distribution of the sample mean approaches a normal distribution, allowing us to make inferences about the population mean.
#
# **6. Code example:**
#
# Here's an example of how to simulate the central limit theorem in Python. We can generate a large number of random samples from a non-normal distribution (e.g., a uniform distribution), calculate the sample means, and plot the distribution of the sample means. As the sample size increases, the distribution of the sample means becomes increasingly normal.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate random samples
n_samples = 100000
sample_sizes = [1, 2, 5, 10, 50]
samples = np.random.uniform(size=(n_samples, max(sample_sizes)))

# Calculate sample means
sample_means = [np.mean(samples[:, :n], axis=1) for n in sample_sizes]

# Plot distribution of sample means
fig, axs = plt.subplots(ncols=len(sample_sizes), figsize=(15, 5))
for i, ax in enumerate(axs):
    ax.hist(sample_means[i], bins=50, density=True)
    ax.set_title(f"Sample size = {sample_sizes[i]}")
plt.show()

# %% [markdown]
# This code generates 100,000 random samples from a uniform distribution, calculates the sample means for various sample sizes, and plots the distribution of the sample means. As you can see from the resulting plots, as the sample size increases, the distribution of the sample means becomes increasingly normal, demonstrating the central limit theorem in action.

# %% [markdown]
# ### **Normal Approximations Using CLT**

# %% [markdown]
# - In many cases, especially when dealing with large sample sizes, the normal distribution is widely used in statistical analysis due to its well-understood properties. The approximations you've mentioned are specific scenarios where other probability distributions are approximated by the normal distribution using the Central Limit Theorem.

# %% [markdown]
# #### **Binomial Distribution Approximation**

# %% [markdown]
# - The binomial distribution describes the number of successes in a fixed number of independent Bernoulli trials (each with a probability of success $p$
#  is the probability of success
#  and $q=1−p$ is the probability of failure ).
# - For a binomial distribution $Bin$($n$,$p$) with a large sample size $n$ and a probability of success $p$, if both $np$ and ${n}$${(1-p)}$ are greater than 5, the distribution of the sum of these binomial variables can be approximated by a normal distribution.
#
# <u> **Approximation Formula** </u>
#
# 👉  Bin(n, p) ∻ N(np, np(1-p)), if np>5 and n(1-p) > 5
#
# This means that when $n$ is large and $p$ is not too close to 0 or 1, you can use the normal distribution with the same mean (${np}$) and standard deviation $\sqrt{np(1-p)}$ to approximate the binomial distribution.

# %% [markdown]
# #### **Poisson Distribution Approximation**

# %% [markdown]
# - The Poisson distribution models the number of events occurring in a fixed interval of time or space, given a known average rate (${\bar{λ}}$)
# - For a Poisson distribution with a large average rate ($λ$), the distribution can be approximated by a normal distribution.
#
# <u> **Approximation Formula** </u>
#
# 👉 Poi($λ$) ∻ $N$($λ$, ${\bar{λ}}$), if $λ$ is large
#
# This approximation is valid when the average rate (${\bar{λ}}$) is relatively large. The normal distribution with the same mean (${\bar{λ}}$) and standard deviation (${\sqrt{λ}}$) can be used to approximate the Poisson distribution.

# %% [markdown]
# #### **Chi-Square Distribution Approximation**
# - The chi-square distribution is often used in statistical inference, especially in hypothesis testing and confidence interval calculations.
#
# - For a chi-square distribution with a large number of degrees of freedom (n), the distribution can be approximated by a normal distribution.
#
# <u> **Approximation Formula** </u>
#
# 👉 $χ_n^2$ ∻ $N$($n, 2n$), if $n$ is large
#
# This approximation holds when the number of degrees of freedom ($n$) is large. The normal distribution with the same mean ($n$) and standard deviation (${\sqrt{2n}}$) can be used to approximate the chi-square distribution.

# %% [markdown]
# ## **Non-Probability Sampling**
# - Non-probability sampling🎲 is a type of sampling technique where not all members of the population have a known and equal chance of being selected into the sample.
#
# - Unlike probability sampling, non-probability sampling methods do not rely on random selection and may introduce various forms of bias into the sample.
# - Non-probability sampling is often used when it is not feasible or practical to implement probability sampling methods.

# %% [markdown]
# ### **Types of Non-Probability Sampling**
# - Judgment or purposive or deliberate sampling
# - Convenience sampling
# - Quota sampling
# - Snow ball sampling

# %% [markdown]
# #### **Judgment or purposive or deliberate sampling**
#
# - Judgment sampling, also known as purposive or deliberate sampling, involves selecting specific individuals or cases based on the researcher's judgment or specific criteria.
# - This method is often used when the researcher believes that certain participants can provide valuable insights into the research topic.
#
# <u>**Example:**</u> Imagine a study 📑 focusing on the experiences of successful entrepreneurs 👨‍💼💰 . The researcher selects participants who have a track record of starting and managing successful businesses ‍💼💰. In this case, the participants are chosen deliberately because they possess the expertise and knowledge relevant to the research question.

# %% [markdown]
# #### **Convenience Sampling**
#
# - Convenience sampling involves selecting individuals who are easily accessible or convenient for the researcher to reach.
# - This method is simple and quick but may lead to biased results.
#
# <u> **Example:** </u> Consider a study investigating student 🧑‍🎓opinions about a new school policy. The researcher 🧑‍🔬 collects responses from students who happen to be in the same room during a break. While this method is convenient, it may not represent the entire student population's opinions accurately.

# %% [markdown]
# #### **Quota Sampling**
#
# - Quota sampling involves dividing the population into subgroups (quotas) based on specific characteristics and then selecting participants from each subgroup.
# - Quota sampling aims to ensure that the sample reflects the population's diversity in terms of the selected characteristics.
#
# <u> **Example:** </u> Suppose a survey  aims to understand preferences for different types of smartphone 📱 brands across age groups. The researcher 🧑‍🔬sets quotas for age groups (e.g., 18-25, 26-40, 41-60), and within each quota, selects participants randomly or through convenience sampling. This approach ensures representation from different age segments.

# %% [markdown]
# - Snowball sampling is used when the population is hard to reach, and participants are recruited through referrals from existing participants.
# - It's often used in studies involving hidden or marginalized populations.
#
# <u>**Example:**</u> Imagine a study investigating the experiences of individuals who have experienced homelessness 🏡. The researcher starts with a small group of participants who are willing to share their experiences. Then, these initial participants refer the researcher to others within the homeless 🏘 community, forming a "snowball" effect. This method allows researchers to access a population that may not be easily accessible through traditional sampling methods.

# %% [markdown]
# ## **Sample Size Determination**

# %% [markdown]
# ### **Sum of Independent R.V.**

# %% [markdown]
# #### **Expected Value (Mean) of the Sum of Independent Random Variables**

# %% [markdown]
# Suppose we have n independent random variables, X1, X2, ..., Xn. Each of these random variables has its own expected value (mean), denoted as E[Xi], where i ranges from 1 to n.
#
# The expected value of the sum of these independent random variables, denoted as E[X1 + X2 + ... + Xn], is the sum of their individual expected values:
#
# *   E[X1+X2+....+Xn] = E[X1]+E[X2]+....+E[Xn]
#
# This means that the expected value of the sum of independent random variables is simply the sum of their individual expected values.

# %% [markdown]
# #### **Variance of the Sum of Independent Random Variables**

# %% [markdown]
# Similarly, the variance of the sum of independent random variables, denoted as var[X1 + X2 + ... + Xn], is the sum of their individual variances:
#
#
# *   var[X1+X2+....+Xn] = var[X1]+var[X2]+....+var[Xn]
#
# Again, this equation states that the variance of the sum of independent random variables is the sum of their individual variances.

# %% [markdown]
# #### **Let's go down little deep**

# %% [markdown]
# When dealing with independent random variables, their behavior does not affect each other, and their combined outcomes can be analyzed using the properties of expected values and variances. These equations allow us to calculate the expected value and variance of the sum of these variables by simply adding up their individual expected values and variances.

# %% [markdown]
# #### **Example**
#
# Let's say you're rolling two fair six-sided dice 🎲 . Each die has an expected value of ${\frac{(1+2+3+4+5+6)}{6}}$ = 3.5 and a variance of ${\frac{((1-3.5)^2 + (2-3.5)^2 + ... + (6-3.5)^2)}{6}}$ = 2.9167.
#
# Now, if you want to find the expected value and variance of the sum of the two dice rolls:
#
# Expected value: E[X1 + X2] = E[X1] + E[X2] = 3.5 + 3.5 = 7
# Variance: var[X1 + X2] = var[X1] + var[X2] = 2.9167 + 2.9167 = 5.8334
#
# This demonstrates how you can use the properties of expected values and variances to analyze the combined outcomes of independent random variables.

# %% [markdown]
# ## **Sampling Bias**

# %% [markdown]
# ### **Definition of a statistic**

# %% [markdown]
# 📊   A statistic is a function of X only and does not involve any unknown
# parameters.
#
# 🔢   Examples:
#
# 👉  Sample Mean, $X̄ = \frac{1}{n} *Σ X_i$
#
# 👉  Sample Variance, $S^2 = \frac{1}{n-1} * \sum (X_i - \bar{X})^2$
#
# 🔢   Non-Example:
#
# 👉  $\frac{1}{n} * \sum (X_i - \mu)^2$ is not a statistic, unless μ is known.
#
# 🎲   A statistic can be generally denoted by g(X) . Since a statistic is a function of random variables, it will be a random variable itself and will have a distribution, its sampling distribution.

# %% [markdown]
# ### **The Sample Mean**

# %% [markdown]
# 🔢   Suppose that we have n independent and identically distributed
# random variables, $X_i$, i = 1, 2,..., n, each with mean μ and variance $σ^2$
#
# 👉   Sample Mean, $\bar{X} = \frac{1}{n} * \sum X_i$
#
# 👉  $E[\bar{X}] = \mu$
#
# 👉  $Var[\bar{X}] = \frac{\sigma^2}{n}$
#
# 👉  $SD[\bar{X}] = \frac{\sigma}{\sqrt{n}}$
#
# 👉  For large n, $\bar{X} \sim N(\mu, \frac{\sigma^2}{n})$
#
# 📊   This result is known as the Central Limit Theorem(CLT) or the z result.

# %% [markdown]
# ### **The Sample Variance**

# %% [markdown]
# 🔢 Suppose that we have n independent and identically distributed
# random variables, $X_i$, i = 1, 2,..., n, each with mean μ and variance $σ^2$.
#
# 👉 Sample Variance, $S^2 = \frac{1}{n-1} * \sum (X_i - \bar{X})^2$
#
# 👉 $E[S^2] = \sigma^2$
#
# 👉 $var[S^2]$ -> Dependent on population distribution
#
# 📊 The sampling distribution of $S^2$ when sampling from a normal population, with mean μ and variance $σ^2$, is: $\frac{(n-1)S^2}{\sigma^2} \sim \chi^2_{n-1}$

# %% [markdown]
# ### **The t result**

# %% [markdown]
# 🔍 In most cases, $σ^2$ is not known and so the z result cannot be used in such cases. We use the t result in such cases.
#
# 👉 $t = \frac{\bar{X} - \mu}{S/\sqrt{n}}$  ~  $t_{n-1}$
#
# 📊 This is the t result or the t sampling distribution.
#
# 👉 This result is valid for samples from normal distribution only.
#
# 📈 The t distribution is symmetrical about zero.

# %% [markdown]
# ### **The F result**

# %% [markdown]
# 📊 If independent random samples of size n1 and n2 respectively are taken from normal populations with variances $σ_1^2$ and $σ_2^2$, then
#
# 👉 $F = \frac{S_1^2/\sigma_1^2}{S_2^2/\sigma_2^2}$ ~ $F_{n_1-1,n_2-1}$
#
# 📊 This result is valid for samples from normal distribution only.

# %% [markdown]
# ### **Point Estimation**

# %% [markdown]
# #### **Method of Moments**

# %% [markdown]
# 📊 The basic principle is to equate population moments (i.e the means, variances, etc of the theoretical model) to corresponding sample moments (i.e the means, variances, etc of the sample data observed) and solve for the parameter(s).
#
# 👉 One parameter case:
#
#
#    $E(X) = \frac{1}{n} \sum_{i=1}^{n} X_i$
#
# 👉 Two parameter case:
#
#    $E(X) = \frac{1}{n} \sum_{i=1}^{n} X_i$ OR    $E(X^2) = \frac{1}{n} \sum_{i=1}^{n} X^2_i$

# %% [markdown]
# #### **Method of Moments Example**

# %% [markdown]
# A random sample from a Exp(λ) distribution is as follows:
#
# 14.84, 0.19, 11.75, 1.18, 2.44, 0.53
#
# Calculate the method of moments estimate for λ.
#
# x̄ = (14.84+0.19+11.75+1.18+2.44+0.53)/6 = 5.155
#
# E[X] = $\frac{1}{λ}$
#
# According to method of moments: E[X] = x̄ -> 1/λ = 5.155 -> λ = 0.1940

# %% [markdown]
# #### **Method of Maximum Likelihood**

# %% [markdown]
# 📈 The method of maximum likelihood is widely regarded as the best
# general method of finding estimators.
#
# 📊 Likelihood of a sample x1,x2,...,xn from a population with density or probability function f (x; θ) is given by:
#
#   $L(\theta) = \prod_{i=1}^n f(x_i; \theta)$
#
# 🔍 Differentiating the likelihood or log likelihood with respect to the
# parameter and setting the derivative to zero gives the maximum
# likelihood estimator (MLE) for the parameter (denoted by $\hat{\theta}$ ).

# %% [markdown]
# #### **Activity:True or False**
#
# * **Q1:**The Central Limit Theorem (CLT) states that for large sample sizes, the sampling distribution of the sample mean approaches a normal distribution, regardless of the shape of the parent population distribution.
#
#
# * **Q2:**The sample variance, denoted by S^2, is an unbiased estimator of the population variance.
#
#
#
# * **Q3:** The F-distribution is used to compare variances of two independent samples taken from normally distributed populations.
#
#
#
# * **Q4:**The t-distribution is symmetrical about its mean.
#
#
#
# * **Q5**In the method of maximum likelihood estimation, the goal is to minimize the likelihood function.

# %% [markdown]
# ##### **Answers**
# * **A1** True
# * **A2** :True
# * **A3**  True
# * **A4** False (It is symmetrical about zero)
# * **A5** False (The goal is to maximize the likelihood function)

# %% [markdown]
# #### **Method of Maximum Likelihood Example**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### **Properties of Estimators**

# %% [markdown]
# 🔍 Let us take a random sample X = (X1,X2,...,Xn) from a distribution with an unknown parameter θ and g(X) is an estimator of θ.
#
# 👉 Bias = E[g(X)] - θ
#
# 👉 If bias of an estimator is zero, it is said to be an unbiased estimator.
#
# 🔑 Important: $S^2$ is an unbiased estimator of $σ^2$. Hence, we take (n-1) instead of n.
#
# 📊 Mean Squared Error, MSE(g(X)) = $E[(g(X) - θ)^2] = bias^2 + variance$
#
# 💡 Estimator with a lower MSE is said to be more efficient.

# %% [markdown]
# ### **Activity:Fill in the Blanks**
#
# * **Q1** The ____________ of a statistic is the difference between the expected value of the statistic and the true value of the parameter being estimated.
#
#
#
# * **Q2** The sample mean is calculated by summing up all the data values and dividing by the ____________.
#
#
#
# * **Q3** The sampling distribution of the sample mean is approximately normal when the sample size is ____________.
#
#
#
# * **Q4** The sample variance, S^2, follows a ____________ distribution when sampling from a normal population.

# %% [markdown]
# #### **Answers**
#
# * **A1:** Bias
# * **A2:** Sample size (n)
# * **A3:** Large
# * **A4:** Chi-square (χ^2) distribution

# %% [markdown]
# #**Summary**

# %% [markdown]
# ###**📚 What Did You Learn? 🤔📝**
#
# In this comprehensive study of statistical concepts, you have gained valuable insights into:
#
# 🔹 **Random Sample:** Understanding the characteristics and importance of random sampling in statistical analysis.
#
# 🔹 **Random Sample Notation:** Familiarizing yourself with the notation and representation of random samples using capital X's.
#
# 🔹 **Sum of Independent R.V.:** Learning the properties of sums of independent random variables, facilitating calculations in statistical studies.
#
#
# 🔹 **Normal Approximations Using CLT:** Exploring the Central Limit Theorem and its application to approximating distributions.
#
# 🔹 **The Sample Variance:** Understanding the sample variance as an unbiased estimator of population variance and its distribution.
#
# 🔹 **The t result:** Recognizing the t-distribution as an alternative when population variance is unknown.
#
# 🔹 **The F result:** Exploring the F-distribution in scenarios with two independent samples from normal populations.
#
# 🔹 **Point Estimation:** Embracing the method of moments and maximum likelihood as techniques for estimating parameters.
#
# 🔹 **Method of Moments Example:** Applying the method of moments to estimate parameters using a sample from an exponential distribution.
#
# 🔹 **Method of Maximum Likelihood:** Understanding the widely acclaimed method for finding estimators based on the likelihood of samples.
#
# 🔹 **Properties of Estimators:** Uncovering the properties of estimators, including bias, variance, and mean squared error.
#
# By mastering these concepts, you are now equipped with a robust statistical foundation to analyze data and make informed decisions. 🚀🌟
#
# ##**🚀 Best Practices and Tips for Mastering Statistics 🤓📈**
#
# Here are some tips to help you excel in the realm of statistics and become a proficient data analyst:
#
# 🔹 Practice regularly with diverse datasets to reinforce your understanding and skills.
#
# 🔹 Familiarize yourself with statistical software packages like R or Python for efficient data analysis.
#
# 🔹 Understand the assumptions and conditions under which certain statistical methods are applicable.
#
# 🔹 Stay up-to-date with advancements in statistical techniques and methodologies.
#
# 🔹 Engage in collaborative projects or join statistical communities to learn from others.
#
# 🔹 Seek real-world applications and case studies to contextualize statistical concepts.
#
# 🔹 Pay attention to the interpretation of results and their implications in decision-making.
#
# By adopting these best practices, you can become a confident statistician capable of tackling complex data challenges! 💪🔍📊
#
# ##**🤔 Shortcomings to Watch Out for When Learning Statistics 🙅‍♂️📉**
#
# While statistics is a powerful tool, be cautious of potential pitfalls during your learning journey:
#
# 🔹 Overreliance on formula memorization without grasping the underlying concepts.
#
# 🔹 Neglecting to verify assumptions and limitations of statistical methods.
#
# 🔹 Focusing solely on mathematical aspects without understanding real-world applications.
#
# 🔹 Succumbing to confirmation bias in interpreting statistical results.
#
# 🔹 Underestimating the significance of sample size and representativeness.
#
# 🔹 Overlooking the importance of communicating statistical findings effectively.
#
# 🔹 Avoiding interdisciplinary collaboration and insights from other domains.
#
# By being mindful of these potential shortcomings, you can enhance your statistical prowess and make more impactful contributions in data analysis. 🧠📈💡

# %% [markdown]
# #**➕ Additional Reading ➕**

# %% [markdown]
# Explore these additional resources to deepen your understanding of statistics and its applications:
#
# 🔹 "Introduction to Probability and Statistics" by William Mendenhall, Robert J. Beaver, and Barbara M. Beaver.
#
# 🔹 "Statistical Inference" by George Casella and Roger L. Berger.
#
# 🔹 "The Art of Data Science" by Roger D. Peng and Elizabeth Matsui.
#
# 🔹 "All of Statistics: A Concise Course in Statistical Inference" by Larry Wasserman.

# %% [markdown]
# ###**Mnemonic:**
#
# 🎉 To excel in statistics, remember the mnemonic "STATS":
#
# 🔹 S: Start with clear objectives and hypotheses for your analysis.
#
# 🔹 T: Test assumptions and ensure data quality before proceeding.
#
# 🔹 A: Analyze your data using appropriate statistical methods.
#
# 🔹 T: Thoroughly interpret results in the context of your research question.
#
# 🔹 S: Summarize and visualize findings for effective communication.
#
# By following the "STATS" mnemonic, you can navigate the statistical landscape with confidence and precision! 📊💻🧑‍🔬

# %% [markdown]
# ###**Read or Practice Yourselves:**
#
# 🔹 Participate in statistical competitions and challenges on platforms like Kaggle.
#
# 🔹 Implement statistical models and hypothesis tests using programming languages like R or Python.
#
# 🔹 Explore research papers and journals in statistical methodology and applications.
#
# 🔹 Engage in data-driven projects or consulting to apply statistical concepts in real-world scenarios.

# %% [markdown]
# ##**Additional Resources:**
#
# For more in-depth exploration of statistical concepts and applications, consider these additional resources:
#
# 🔹 "Principles of Statistics" by M.G. Bulmer.
#
# 🔹 "An Introduction to Mathematical Statistics and Its Applications" by Richard J. Larsen and Morris L. Marx.
#
# 🔹 http://www.stat.yale.edu/Courses/1997-98/101/sampinf.htm
#
# 🔹 https://byjus.com/maths/statistical-inference/

# %% [markdown]
# With these resources at your disposal, you can further expand your statistical knowledge and become a proficient data analyst capable of making data-driven decisions that drive innovation and insights! 🤩📊🧑‍💻

# %% [markdown]
# # **Try it Yourself 📃**
#
# Are you ready to put your coding skills to the test and gain practical knowledge? We have some exciting coding questions waiting for you to solve! 🚀
#
# Your task is to attempt the coding questions associated with this lesson. These challenges have been thoughtfully designed to reinforce your understanding of the concepts covered in the course. You can find them in your dashboard under this lesson.
#
# Don't be shy! Share your findings, experiences, and any insights you gained while tackling these coding questions on the AlmaBetter community platform. Engage in discussions, help each other out, and celebrate your victories together!
#
# Remember, coding is not just about learning theory; it's about applying that knowledge to solve real-world problems. So, dive in, experiment, and have fun while honing your coding skills!
# Let's learn, grow, and inspire each other as a vibrant community of passionate learners. Happy coding! 💻 😊

# %% [markdown]
# ## **🏃 Task: 1 🏃**

# %% [markdown]
# ###**Task1:**
#
# Consider a sample of 10 students' test scores: {75, 80, 92, 68, 85, 77, 81, 79, 90, 88}. Calculate the sample mean.

# %% [markdown]
# ###**Task *2*:**
# Consider a sample of 10 students' test scores: {75, 80, 92, 68, 85, 77, 81, 79, 90, 88}. Calculate the sample variace.
