# %% [markdown]
# # **Session Flow:**

# %% [markdown]
# **Learning Objective:**
#
#   * Introduction
#   * Theme
#   * Primary Goals
#
# **Learning Material:**
#
#   * Introduction to Supervised Models - Classification
#   * Logistic Regression
#     - What is logistic regression?
#     - Activity 1: True/False
#     - Implementing logistic regression
#     - Evaluation Metrics used for Classification
#     - Defining the cost function
#     - Activity 2: Fill in the Blanks
#
# **Summary:**
#
#   * What did we learn?
#   * Best Practices
#   * Shortcomings
#
# **Enhance your Knowledge:**
#
#   * Additional Reading
#   * Mnemonic
#   * Additional Resources
#
# **Try it Yourself:**
#
#   * Take Home Assignment
#   * Social Engagement

# %% [markdown]
# # **Learning Objective:**

# %% [markdown]
# ### **Introduction:**
#
# **Understanding Classification**: We'll start by exploring what classification is in the context of machine learning and why it's so crucial in various applications, from spam detection to medical diagnosis.
#
# **Logistic Regression**: One of the foundational models for classification is logistic regression. We'll answer the question, "What is logistic regression?" and then show you how to implement it. You'll learn about the concept, the mathematics behind it, and see how it can be applied to real-world data.
#
# **Evaluation Metrics for Classification**: Understanding how to evaluate the performance of your classification model is key. We'll cover various metrics like accuracy, precision, recall, and more. We'll also discuss the cost function, which is central to the optimization of logistic regression models.
#
#
#
# By the end of this lesson, you'll have a solid understanding of these key classification models and techniques, empowering you to tackle real-world data classification problems. Let's get started!

# %% [markdown]
# ### **Theme:**
#
# "Unlocking the Secrets of Classification: A Journey through Logistic Regression and Decision Trees"
#
# In today's lesson, we embark on an enlightening journey through the realm of supervised machine learning, specifically honing in on the art and science of classification. We'll demystify the complexities behind logistic regression, unveiling its power in deciphering categorical outcomes from a swirl of data. As we delve deeper, we'll unravel the intricacies of evaluation metrics, ensuring our model's prowess is measured accurately. Through interactive activities and practical implementation, this session is not just about learning concepts but experiencing the magic of transforming data into decisions. Join us as we unlock the secrets of classification, one prediction at a time!

# %% [markdown]
# ### **Primary Goals:**
#
# 1. **Comprehensive Understanding of Classification**: To ensure a deep understanding of what classification is in the context of machine learning, its significance, and its real-world applications.
#
# 2. **Mastering Logistic Regression**: To explain the concept of logistic regression thoroughly, demonstrate its implementation, and elucidate the mathematical principles that underpin this method.
#
# 3. **Grasping Evaluation Metrics**: To provide a clear understanding of various evaluation metrics critical for assessing classification models, emphasizing their importance in model performance validation.

# %% [markdown]
# # **Learning Material:**

# %% [markdown]
# ## **Introduction to Supervised Models - Classification**

# %% [markdown]
# ## <b> <u>Introduction: What is Logistic Regression? </u></b>

# %% [markdown]
# Imagine you have a magic machine that helps you decide if something is a **"Yes"** or a **"No"**. Let's say you want to know if it will rain today or not.
#
# You tell the machine some things, like how cloudy it is, if you see dark clouds, or if it's very windy. The machine takes these 'clues' and decides if these clues together mean it's going to rain (which is a "Yes") or not (which is a "No").
#
# Logistic regression is like this magic machine. It looks at the information (like how cloudy it is) and calculates the chances of something being a **"Yes"** or a **"No"**. It's like a smarter way of making a guess. So, if it's very cloudy and windy, the machine might say, "Yes, it looks like it will rain." But if it's a little cloudy and not windy, the machine might say, "No, it probably won't rain."

# %% [markdown]
# ![maxresdefault.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# In our simple example, we'll use two features: "cloudiness" and "windiness." These features will be numbers (let's say, on a scale from 0 to 10) where higher numbers mean more cloudiness or windiness.
#
#
#
#
# Logistic regression is a classification algorithm that predicts the probability of an outcome that can only have two values (i.e. a dichotomy). A logistic regression produces a logistic curve, which is limited to values between 0 and 1. Logistic regression models the probability that each input belongs to a particular category.
#
# **Logistic regression** is an excellent tool to know for classification problems, which are problems where the output value that we wish to predict only takes on only a small number of discrete values. Here we'll focus on the binary classification problem, where the output can take on only two distinct classes.
#
# First, we need some sample data to train our logistic regression model. Then, we will use the model to predict whether it will rain or not based on new cloudiness and windiness values.

# %% [markdown]
# Here's a step-by-step Python code example:
#
# 1. **Import Necessary Libraries**: We'll use `numpy` for handling data and `sklearn` for logistic regression.
# 2. **Create Sample Data**: We'll create a small dataset to train our model.

# %%
from sklearn.linear_model import LogisticRegression
import numpy as np
import pandas as pd

# Sample data (cloudiness, windiness) and labels (0 for no rain, 1 for rain)
# Let's say 0-5 is less likely for rain and 6-10 is more likely for rain
X = np.array([[1, 2], [2, 3], [3, 1], [5, 2], [7, 8], [8, 7], [9, 9], [6, 6]])
y = np.array([0, 0, 0, 0, 1, 1, 1, 1])

df = pd.DataFrame(X, columns = ['cloudiness','windiness'])
df['rain'] = y
df
# Out:
#    cloudiness  windiness  rain
# 0           1          2     0
# 1           2          3     0
# 2           3          1     0
# 3           5          2     0
# 4           7          8     1
# 5           8          7     1
# 6           9          9     1
# 7           6          6     1

# %% [markdown]
# 3. **Train the Logistic Regression Model**: We'll use our sample data to train the model.
# 4. **Make Predictions**: We'll use the trained model to predict whether it will rain or not based on new data.

# %%
# Create a logistic regression model
model = LogisticRegression()

# Train the model
model.fit(X, y)

# Now, let's predict if it will rain with new data
# Example: Cloudiness = 4, Windiness = 6
new_data = np.array([[4, 6]])
prediction = model.predict(new_data)

# The prediction result: 0 for no rain, 1 for rain
prediction[0]
# Out:
# np.int64(1)

# %% [markdown]
# The logistic regression model predicted a "1" for our new data (Cloudiness = 4, Windiness = 6). In our simple example, "1" means that the model predicts it will rain, given these conditions of cloudiness and windiness.

# %% [markdown]
# ### **Math Behind the Example:**

# %% [markdown]
# Logistic regression works by using a mathematical equation to predict the probability of a binary outcome (like rain or no rain, represented as 1 or 0). The core of this equation is the logistic function, which transforms any input into a value between 0 and 1, making it useful for predicting probabilities.
#
# Here's a step-by-step breakdown of the math behind logistic regression, using our rain prediction example:
#
# 1. **The Logistic Function**: The logistic function, also known as the sigmoid function, is given by:
#    $$[ \sigma(z) = \frac{1}{1 + e^{-z}}]$$
#    where \( e \) is the base of the natural logarithm and \( z \) is a linear combination of the input features.
#
# 2. **Linear Combination of Inputs**: For our example with cloudiness and windiness as features, the linear combination \( z \) can be represented as:
#
#    $$[ z = b + w_1 \times \text{cloudiness} + w_2 \times \text{windiness}]$$
#
#    Here, \( b \) is the bias term (intercept), and $( w_1, w_2)$ are the weights (coefficients) assigned to the cloudiness and windiness features, respectively. These weights are what the model learns during training.
#
# 3. **Making Predictions**: To predict whether it will rain or not, we calculate the value of \( z \) using the weights and bias learned by the model. Then, we apply the logistic function to \( z \) to get a probability:
#
#    $$[ \text{Probability of Rain} = \sigma(z) = \frac{1}{1 + e^{-(b + w_1 \times \text{cloudiness} + w_2 \times \text{windiness})}}]$$
#
# 4. **Interpreting the Output**: The output of the logistic function is a probability between 0 and 1. If this probability is greater than a certain threshold (usually 0.5), we predict "rain" (1); otherwise, we predict "no rain" (0).
#
# Let's use the weights and bias from our trained logistic regression model to calculate the probability of rain for the new data point (Cloudiness = 4, Windiness = 6) using this mathematical approach.

# %%
# Retrieve the learned weights (coefficients) and bias (intercept) from the model
weights = model.coef_[0]
bias = model.intercept_[0]

# Print the weights and bias
print("Weights:", weights)
print("Bias Term:", bias)

# New data point
cloudiness, windiness = 4, 6

# Calculate the linear combination (z)
z = bias + weights[0] * cloudiness + weights[1] * windiness

# Apply the logistic (sigmoid) function to compute the probability
probability_of_rain = 1 / (1 + np.exp(-z))

print("Probability of raining:", probability_of_rain)
# Out:
# Weights: [0.53298223 0.82509307]
# Bias Term: -6.404848430627816
# Probability of raining: 0.6632115264942609

# %% [markdown]
# The calculated probability of rain for the new data point (Cloudiness = 4, Windiness = 6) is approximately 0.663, or 66.3%. This means, according to our logistic regression model, there's a 66.3% chance of rain given these conditions.
#
# In logistic regression, if this probability is above the usual threshold of 0.5, we predict the outcome as "1" (rain in this case). Since our probability is above 0.5, it aligns with our earlier prediction of rain. This demonstrates how logistic regression mathematically estimates probabilities and makes predictions based on input features.

# %% [markdown]
# ### **Activity 1: True/False**

# %% [markdown]
# Sure, here are a few True/False statements based on logistic regression and general classification concepts. After each statement, I'll provide an explanation:
#
# 1. **True/False**: Logistic regression can only be used for binary classification problems.
#
# 2. **True/False**: In logistic regression, the output is the probability of the dependent variable being true.
#
# 3. **True/False**: Increasing the threshold for classification in logistic regression will increase the number of true positives.

# %% [markdown]
# #### **Activity 1 Answers:**

# %% [markdown]
# 1. - **Answer**: False
#    - **Explanation**: While logistic regression is commonly used for binary classification, it can also be extended to handle multi-class classification problems through techniques like one-vs-rest (OvR) or multinomial logistic regression.
#
# 2.    - **Answer**: True
#    - **Explanation**: Logistic regression models the probability that the dependent variable belongs to a particular class. In binary classification, this is often interpreted as the probability of the dependent variable being true or belonging to the '1' class.
#
# 3.   - **Answer**: False
#    - **Explanation**: Increasing the threshold for classification in logistic regression will typically decrease the number of true positives, as it becomes stricter about what is classified as positive. This may increase the number of false negatives.

# %% [markdown]
# ## <b> <u> Implementing Logistic Regression in Python </u></b>

# %% [markdown]
# Let us now start implementing what we learned from the previous section into python codes. We will use the Telco Customer Churn data.
#
# ### <b>What is Churn Prediction? </b>
#
# Churn prediction is analytical studies on the possibility of a customer abandoning a product or service. The goal is to understand and take steps to change it before the customer gives up the product or service.
#
# ### <b>About Data </b>
#
# * customerID : Customer ID
# * gender : Whether the customer is a male or a female
# * SeniorCitizen : Whether the customer is a senior citizen or not (1, 0)
# * Partner : Whether the customer has a partner or not (Yes, No)
# * Dependents : Whether the customer has dependents or not (Yes, No)
# * tenure : Number of months the customer has stayed with the company
# * PhoneService : Whether the customer has a phone service or not (Yes, No)
# * MultipleLines : Whether the customer has multiple lines or not (Yes, No, No phone service)
# * InternetService : Customer’s internet service provider (DSL, Fiber optic, No)
# * OnlineSecurity : Whether the customer has online security or not (Yes, No, No internet service)
# * OnlineBackup : Whether the customer has online backup or not (Yes, No, No internet service)
# * DeviceProtection : Whether the customer has device protection or not (Yes, No, No internet service)
# * TechSupport : Whether the customer has tech support or not (Yes, No, No internet service)
# * StreamingTV : Whether the customer has streaming TV or not (Yes, No, No internet service)
# * StreamingMovies : Whether the customer has streaming movies or not (Yes, No, No internet service)
# * Contract : The contract term of the customer (Month-to-month, One year, Two year)
# * PaperlessBilling : Whether the customer has paperless billing or not (Yes, No)
# * PaymentMethod : The customer’s payment method (Electronic check, Mailed check, Bank transfer (automatic), Credit card (automatic))
# * MonthlyCharges : The amount charged to the customer monthly
# * TotalCharges : The total amount charged to the customer
# * Churn : Whether the customer churned or not (Yes or No)

# %% [markdown]
# **Dataset Link:** https://drive.google.com/file/d/1dFkT-RNfbogbL76rx3O-LgMte2XcuKpg/view?usp=sharing

# %% [markdown]
# ![Churn.png](data:image/png;base64,...)

# %% [markdown]
# #### **Dataset initialization**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")
print("Dataset size")
print("Rows {} Columns {}".format(df.shape[0], df.shape[1]))
# Out:
# Dataset size
# Rows 7043 Columns 21

# %%
print("Columns and data types")
pd.DataFrame(df.dtypes).rename(columns = {0:'dtype'})
# Out:
# Columns and data types
#                     dtype
# customerID         object
# gender             object
# SeniorCitizen       int64
# Partner            object
# Dependents         object
# tenure              int64
# PhoneService       object
# MultipleLines      object
# InternetService    object
# OnlineSecurity     object
# OnlineBackup       object
# DeviceProtection   object
# TechSupport        object
# StreamingTV        object
# StreamingMovies    object
# Contract           object
# PaperlessBilling   object
# PaymentMethod      object
# MonthlyCharges    float64
# TotalCharges       object
# Churn              object

# %% [markdown]
# That's a lot of columns, to simplify our experiment we will only use 2 features **tenure** and **MonthlyCharges** and the target would be **Churn**  of course. Let us do a simple EDA and visualization on our features and target.

# %% [markdown]
# #### EDA: Independent variables

# %%
fig = plt.figure(figsize=(9, 6))
ax = fig.gca()
df.boxplot(column = 'MonthlyCharges', by = 'Churn', ax = ax)
ax.set_ylabel("MonthlyCharges")
plt.show()

# %%
fig = plt.figure(figsize=(9, 6))
ax = fig.gca()
df.boxplot(column = 'tenure', by = 'Churn', ax = ax)
ax.set_ylabel("Tenure")
plt.show()

# %% [markdown]
# #### <b> Insights from our simple EDA: </b>
# * We can see a difference between our target classes on tenure as you can see in the second boxplot, which is good because our model (Logistic Regression) may use this to separate the two classes.
# * There is also a slight difference between our target classes on monthly charges as shown in the first boxplot.

# %% [markdown]
# Before we start predicting, an important step to do is to convert our **Churn** feature, which is a string, into integer. *Yes* will be converted to 1 and *No* will be converted to 0. We will name this new columns a "class".

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df['class'] = df['Churn'].apply(lambda x : 1 if x == "Yes" else 0)
# features will be saved as X and our target will be saved as y
X = df[['tenure','MonthlyCharges']].copy()
y = df['class'].copy()

# %%
df.shape
# Out:
# (7043, 22)

# %% [markdown]
# #### <b> Splitting data into train and test

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X,y , test_size = 0.2, random_state = 0)
print(X_train.shape)
print(X_test.shape)
# Out:
# (5634, 2)
# (1409, 2)

# %%
y_train.value_counts()
# Out:
# class
# 0    4133
# 1    1501
# Name: count, dtype: int64

# %%
y_test.value_counts()
# Out:
# class
# 0    1041
# 1     368
# Name: count, dtype: int64

# %% [markdown]
# #### <b>Fitting logistic regression on train data

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression()
clf.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Get the model coefficients and intercept
print(clf.coef_)
print(clf.intercept_)
# Out:
# [[-0.05646759  0.03315394]]
# [-1.77408798]

# %%
# Get the predicted probabilities
train_preds = clf.predict_proba(X_train)
test_preds = clf.predict_proba(X_test)

# %%
# Get the predicted classes
train_class_preds = clf.predict(X_train)
test_class_preds = clf.predict(X_test)

# %% [markdown]
# ####<b> <u>Learning about the confusion matrix

# %% [markdown]
# ![CF.jpg](data:image/jpeg;base64,...)

# %%
# Get the confusion matrix for both train and test
from sklearn.metrics import confusion_matrix
import seaborn as sns

labels = ['Retained', 'Churned']
cm = confusion_matrix(y_train, train_class_preds)
print(cm)

ax= plt.subplot()
sns.heatmap(cm, annot=True, ax = ax) #annot=True to annotate cells

# labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(labels)
ax.yaxis.set_ticklabels(labels)
# Out:
# [[3745  388]
#  [ 819  682]]
# [Text(0, 0.5, 'Retained'), Text(0, 1.5, 'Churned')]

# %%
# Get the confusion matrix for both train and test

labels = ['Retained', 'Churned']
cm = confusion_matrix(y_test, test_class_preds)
print(cm)

ax= plt.subplot()
sns.heatmap(cm, annot=True, ax = ax); #annot=True to annotate cells

# labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(labels)
ax.yaxis.set_ticklabels(labels)
# Out:
# [[934 107]
#  [212 156]]
# [Text(0, 0.5, 'Retained'), Text(0, 1.5, 'Churned')]

# %% [markdown]
# ### **Evaluation Metrics for Classification:**

# %% [markdown]
# 1. **Accuracy**: Measures the proportion of correctly predicted observations to the total observations. It's a useful metric when the target classes are well balanced.
#
#   Accuracy tells us what portion of our predictions were correct. It's like checking how many answers you got right on a test out of all the questions.
#
#    $$[ \text{Accuracy} = \frac{\text{Number of Correct Predictions}}{\text{Total Number of Predictions}}]$$

# %%
from sklearn.metrics import accuracy_score
# Get the accuracy scores
test_accuracy = accuracy_score(y_test,test_class_preds)
print("The accuracy on test data is ", test_accuracy)
# Out:
# The accuracy on test data is  0.7735982966643009

# %% [markdown]
# 2. **Precision**: Indicates the proportion of positive identifications that were actually correct. It's particularly useful in scenarios where the cost of a false positive is high.
#
#   Precision tells us how many of the predicted "rain" days were actually rainy. It's like if you guessed which days would be rainy, how often you'd be right.
#
#    $$[ \text{Precision} = \frac{\text{True Positives}}{\text{True Positives} + \text{False Positives}}]$$

# %%
from sklearn.metrics import precision_score
# Get the precision scores
test_precision = precision_score(y_test,test_class_preds)
print("The precision on test data is ", test_precision)
# Out:
# The precision on test data is  0.5931558935361216

# %% [markdown]
# 3. **Recall (Sensitivity)**: Measures the proportion of actual positives that were identified correctly. It's important in cases where missing a positive is costly.
#
#   Recall shows us how many of the actual rainy days we managed to predict correctly. It’s like checking how many rainy days you didn’t miss in your predictions.
#
#    $$[ \text{Recall} = \frac{\text{True Positives}}{\text{True Positives} + \text{False Negatives}}]$$

# %%
from sklearn.metrics import recall_score
# Get the recall scores
test_recall = recall_score(y_test,test_class_preds)
print("The recall on test data is ", test_recall)
# Out:
# The recall on test data is  0.42391304347826086

# %% [markdown]
# 4. **F1-Score**: The harmonic mean of precision and recall, it is a single metric that balances both the concerns of precision and recall in one number.
#
#   The F1-Score combines precision and recall into one number, balancing the two. It's useful when you want a single score to understand your model's accuracy.
#
#    $$[ \text{F1-Score} = 2 \times \frac{\text{Precision} \times \text{Recall}}{\text{Precision} + \text{Recall}}]$$

# %%
from sklearn.metrics import f1_score
# Get the f1 scores
test_f1 = f1_score(y_test,test_class_preds)
print("The f1 score on test data is ", test_f1)
# Out:
# The f1 score on test data is  0.49445324881141045

# %% [markdown]
# 5. **Log Loss (Logistic Loss or Cross-Entropy Loss)**: Measures the performance of a classification model where the prediction is a probability between 0 and 1. Lower log loss values indicate better performance.
#
#    Log Loss measures how close our probability predictions are to the actual outcomes. A lower log loss means better predictions. It's like being scored on how confident and correct your predictions are.
#
#    $$[ \text{Log Loss} = - \sum_{i=1}^{M} \left[ y_i \log(P_i) + (1 - y_i) \log(1 - P_i) \right]]$$

# %%
from sklearn.metrics import log_loss
# Get the log_loss scores
test_log_loss = log_loss(y_test,test_preds[:,1])
print("The log_loss score on test data is ", test_log_loss)
# Out:
# The log_loss score on test data is  0.4686725617004556

# %% [markdown]
# 6. **AUC-ROC**: The Area Under the Receiver Operating Characteristic Curve (ROC AUC) measures the ability of a model to distinguish between the classes. An AUC of 1 indicates a perfect model; an AUC of 0.5 suggests no discriminative power.
#
#    The ROC curve plots the True Positive Rate (TPR) against the False Positive Rate (FPR) at various threshold levels. The AUC is the area under this curve.
#
#    AUC-ROC tells us how well our model can distinguish between two classes (rain or no rain). A higher score means better distinction. Imagine it as measuring how well a doctor can distinguish between sick and healthy patients.

# %%
from sklearn.metrics import roc_auc_score
# Get the roc_auc_score scores
test_roc_auc_score = roc_auc_score(y_test,test_preds[:,1])
print("The roc_auc_score on test data is ", test_roc_auc_score)
# Out:
# The roc_auc_score on test data is  0.7859408282170155

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Assuming you already have your model predictions (probabilities)
# For example, using: predictions = model.predict_proba(X_test)[:, 1]

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, test_preds[:,1])

# Calculate AUC
roc_auc = auc(fpr, tpr)

# Plotting
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# Each of these metrics provides a different insight into the performance of a classification model. It's often useful to consider multiple metrics when evaluating a model, as each has its strengths and weaknesses depending on the specific characteristics of the dataset and the business problem.

# %% [markdown]
# ### **Activity 2: Fill in the Blanks**

# %% [markdown]
# 1. **Basic Understanding**:
#    - Logistic regression is used for _____________ (classification/regression) problems.
#    - The output of a logistic regression model is the _____________ (probability/confidence) of a certain class or event occurring.
#    - In logistic regression, the decision boundary is typically at _____________ (0.5/1.0).
#
# 2. **Model Equation**:
#    - The equation of logistic regression is modeled as the _____________ (logarithm/sigmoid) function of a linear equation.
#    - The sigmoid function maps any real-valued number into another value between _____________ and _____________ (0 and 1/ -1 and 1).
#
# 3. **Interpretation**:
#    - In logistic regression, a coefficient value greater than 0 indicates that as the feature increases, the probability of the target class _____________ (increases/decreases).
#    - If the odds ratio for a predictor in logistic regression is less than 1, it means that the predictor _____________ (increases/decreases) the odds of the target class.
#
# 4. **Application**:
#    - When using logistic regression for a binary classification problem, the two classes are often coded as _____________ and _____________ (0 and 1/True and False).
#    - A common metric to evaluate the performance of a logistic regression model in classification problems is the _____________ (accuracy/R-squared).

# %% [markdown]
# #### **Activity 2 Answers:**

# %% [markdown]
# 1.
# * classification
# * probability
# * 0.5
#
# 2.
# * sigmoid
# * 0, 1
#
# 3.
# * increases
# * decreases
#
# 4.
# * 0, 1
# * accuracy

# %% [markdown]
# # **Summary:**

# %% [markdown]
# ### **What did we learn?**
#
# In today's lesson, we explored several fundamental concepts and techniques in machine learning, focusing particularly on classification models and decision trees.
#
# 1. **Classification and Logistic Regression**:
#    - We started by understanding classification, explaining it through a simple example of sorting toys. Then, we delved into logistic regression, a statistical method for binary classification. We saw how logistic regression uses probabilities to classify data points and went through a Python example demonstrating its application.
#
# 2. **Evaluation Metrics for Classification Models**:
#    - We covered various metrics used to evaluate the performance of classification models, including accuracy, precision, recall, F1-score, log loss, and AUC-ROC. These metrics help in assessing different aspects of a model's performance, like its overall accuracy, the balance between sensitivity and specificity, and its ability to distinguish between different classes.
#
# 3. **Decision Trees**:
#    - We discussed decision trees, a type of model used for classification and regression tasks. Using a simple fruit classification dataset, we showed how to create and train a decision tree using Python and visualized it. We also walked through the mathematical calculations behind decision tree splits, using Gini impurity as a measure for creating the most informative splits.
#
# Throughout the lesson, we emphasized practical understanding through Python examples and visual representations, ensuring a comprehensive grasp of these foundational concepts in machine learning. The session laid the groundwork for more advanced topics, particularly ensemble methods that build upon the idea of decision trees.

# %% [markdown]
# ### **Best Practices:**
#
# When it comes to machine learning, following best practices and tips can significantly enhance the quality and effectiveness of your models. Here are some key points to consider:
#
# 1. **Understanding the Data**:
#    - **Data Exploration**: Before diving into modeling, spend time understanding and exploring your data. This includes checking for missing values, understanding the distribution of variables, and identifying potential correlations.
#    - **Feature Engineering**: Create meaningful features from your data, which can significantly impact the performance of your models.
#
# 2. **Model Selection and Training**:
#    - **Choosing the Right Model**: There's no one-size-fits-all model. Select a model based on the nature of your data and the problem you're solving.
#    - **Cross-Validation**: Use cross-validation techniques to assess the performance of your model. This helps in understanding how your model will generalize to an independent dataset.
#
# 3. **Dealing with Imbalanced Data**:
#    - Imbalanced datasets can bias the model towards the majority class. Techniques like resampling the data, using different metrics (like F1-score instead of accuracy), or using algorithms that handle imbalance can be beneficial.
#
# 4. **Regularization and Pruning**:
#    - To prevent overfitting, use regularization techniques (like L1 or L2 regularization) in your models. In decision trees and ensemble models, pruning can be used to avoid overfitting.
#
# 5. **Hyperparameter Tuning**:
#    - Optimize your model by tuning hyperparameters. Tools like Grid Search or Random Search can systematically work through multiple combinations of parameter tunes, cross-validating as it goes to determine the best combination.
#
# 6. **Model Evaluation and Interpretation**:
#    - Evaluate your model thoroughly using appropriate metrics. Understanding the context and the business problem is crucial in selecting the right metrics.
#    - Interpretability is key, especially in certain industries. Be prepared to explain how your model makes decisions, which might involve using simpler models or model explanation tools.
#
# 7. **Stay Updated and Collaborate**:
#    - Machine learning is a rapidly evolving field. Stay updated with the latest research, tools, and best practices.
#    - Collaborate and seek feedback. Working with others can provide new insights and improve your models.
#
# 8. **Ethics and Bias**:
#    - Be aware of potential biases in your data and model. Strive to build fair and ethical models, especially when they impact individuals directly.
#
# 9. **Scalability and Deployment**:
#    - Plan for scalability. If your model is going to be used in a production environment, consider how it will scale with increasing data or users.
#    - Ensure that the model is deployable. Models often need to be integrated into existing software and systems.
#
# 10. **Continuous Monitoring and Updating**:
#     - Once deployed, continuously monitor your model's performance. Be prepared to update or retrain it as new data becomes available or as the environment changes.
#
# Remember, these are guidelines, not hard rules. The best practices for a given situation depend on the specifics of the problem, the data, and the organizational context.

# %% [markdown]
# ### **Shortcomings:**
#
# While machine learning offers powerful tools for analyzing and predicting data, it's important to be aware of its limitations and challenges:
#
# 1. **Data Quality and Availability**:
#    - **Dependency on Data**: Machine learning models are heavily reliant on data. The quality, quantity, and relevance of the data directly impact the performance of the models.
#    - **Bias in Data**: Models can inadvertently learn and perpetuate biases present in the training data, leading to unfair or unethical outcomes.
#
# 2. **Model Complexity and Interpretability**:
#    - **Overfitting**: Complex models may fit the training data too closely, capturing noise rather than the underlying pattern, and perform poorly on new data.
#    - **Interpretability**: Some advanced models (like deep learning) are often seen as "black boxes" due to their complexity, making it difficult to interpret their decisions.
#
# 3. **Computational Resources**:
#    - Training sophisticated models, particularly deep learning models, can require significant computational resources and time, which might not be feasible for all projects or organizations.
#
# 4. **Generalization and Robustness**:
#    - **Generalization**: A model that performs well on training data may not necessarily perform well on unseen data due to overfitting or biases.
#    - **Adversarial Attacks**: Machine learning models can be sensitive to slight perturbations in the input data, leading to incorrect outputs.
#
# 5. **Scalability and Deployment**:
#    - Deploying machine learning models into a production environment can be challenging. The model needs to be scalable, maintainable, and integrate well with existing systems.
#
# 6. **Ethical and Legal Considerations**:
#    - The use of machine learning, especially in sensitive areas like facial recognition or personal data prediction, raises ethical and legal concerns regarding privacy, consent, and misuse.
#
# 7. **Evolving Technology and Skill Requirements**:
#    - The field of machine learning is rapidly evolving, requiring continuous learning and adaptation.
#    - There is a significant skill gap, and finding the right talent to develop and manage machine learning systems can be challenging.
#
# 8. **Maintenance and Monitoring**:
#    - Machine learning models require ongoing maintenance and monitoring to ensure they remain effective over time. They may need retraining or adjustments as the underlying data patterns change.
#
# Understanding and addressing these shortcomings are crucial for the successful application of machine learning. It's important to approach machine learning projects with a thorough understanding of both their potential and their limitations.

# %% [markdown]
# # **Enhance your Knowledge:**

# %% [markdown]
# ## **Additional Reading:**

# %% [markdown]
# #### In **Logistic Regression**, the log-odds of a categorical response being "true" (1) is modeled as a linear combination of the features:
#
# ### \begin{align*}
#     \log \left({p\over 1-p}\right) &= w_0 + w_1x_1, ..., w_jx_j \nonumber \\
#     &= w^Tx \nonumber
# \end{align*}
#
# #### where:
#
# - #### $w_{0}$ is the intercept term, and $w_1$ to $w_j$ represents the parameters for all the other features (a total of j features).
# - #### By convention of we can assume that $x_0 = 1$, so that we can re-write the whole thing using the matrix notation $w^Tx$.
#
# #### This is called the **logit function**. The equation can be re-arranged into the **logistic function**:
#
# #### $$p = \frac{e^{w^Tx}} {1 + e^{w^Tx}}$$
#
# #### Or in the more commonly seen form:
#
# #### $$h_w(x) = \frac{1}{ 1 + e^{-w^Tx} }$$

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
# %matplotlib inline

# %%
x_values = np.linspace(-5, 5, 100)
y_values = [1 / (1 + np.exp(-x)) for x in x_values]
plt.plot(x_values, y_values)
plt.title('Logsitic Function')
plt.show()

# %% [markdown]
# The **logistic function** has some nice properties. The y-value represents the probability and it is always bounded between 0 and 1, which is want we wanted for probabilities. For an x value of 0 you get a 0.5 probability. Also as you get more positive x value you get a higher probability, on the other hand, a more negative x value results in a lower probability.

# %% [markdown]
# ### <b><u> Defining the cost function for Logistic Regression </b>

# %% [markdown]
# When utilizing logistic regression, we are trying to learn the $w$ values in order to maximize the probability of correctly classifying our classes. Let's say someone did give us some $w$ values of the logistic regression model, how would we determine if they were good values or not? What we would hope is that for the household of class 1, the probability values are close to 1 and for the household of class 0 the probability is close to 0.
#
# But we don't care about getting the correct probability for just one observation, we want to correctly classify all our observations. If we assume our data are independent and identically distributed (think of it as all of them are treated equally), we can just take the product of all our individually calculated probabilities and that becomes the objective function we want to maximize. So in math:
#
# $$\prod_{class1}h_w(x)\prod_{class0}1 - h_w(x)$$
#
# The $\prod$ symbol means take the product of the $h_w(x)$ for the observations that are classified as that class. You will notice that for observations that are labeled as class 0, we are taking 1 minus the logistic function. That is because we are trying to find a value to maximize, and since observations that are labeled as class 0 should have a probability close to zero, 1 minus the probability should be close to 1. This procedure is also known as the **maximum likelihood estimation**.
#
# Next we will re-write the original cost function as:
#
# #### $$\ell(w) = \sum_{i=1}^{N}y_{i}log(h_w(x_{i})) + (1-y_{i})log(1-h_w(x_{i}))$$
#
# #### where:
#
# - We define $y_{i}$ to be 1 when the $i_{th}$ observation is labeled class 1 and 0 when labeled as class 0, then we only compute $h_w(x_{i})$ for observations that are labeled class 1 and $1 - h_w(x_{i})$ for observations that are labeled class 0, which is still the same idea as the original function.
#
# - Next we'll transform the original $h_w(x_{i})$ by taking the log. As we'll later see this logarithm transformation will make our cost function more convenient to work with, and because the logarithm is a monotonically increasing function, the logarithm of a function achieves its maximum value at the same points as the function itself. When we take the log, our product across all data points, it becomes a sum.
#
# - The $N$ simply represents the total number of the data.
#
# Often times you'll also see the notation above be simplified in the form of a maximum likelihood estimator:
#
# #### $$ \ell(w) = \sum_{i=1}^{N} log \big( P( y_i \mid x_i, w ) \big) $$
#
# The equation above simply denotes the idea that , $\mathbf{w}$ represents the parameters we would like to estimate the parameters $w$ by maximizing conditional probability of $y_i$ given $x_i$.
#
# Now by definition of probability in the logistic regression model:
#
# ####  $h_w(x_{i}) = \frac{1}{1 + e^{-w^T x_i}}$ and $1- h_w(x_{i}) = \frac{e^{ -w^T x_i }} {1 + e^{ -w^T x_i } }$.
#
# By substituting these expressions into our $\ell(w)$ equation and simplifying it further we can obtain  a simpler expression.

# %% [markdown]
# #### $$
# \begin{align}
# \ell(w)
# &= \sum_{i=1}^{N}y_{i}log(h_w(x_{i})) + (1-y_{i})log(1-h_w(x_{i})) \nonumber \\
# &= \sum_{i=1}^{N} y_{i} log( \frac{1}{ 1 + e^{ -w^T x_i } } ) + ( 1 - y_{i} )
# log( \frac{ e^{ -w^T x_i } }{ 1 + e^{ -w^T x_i } } ) \nonumber \\
# &= \sum_{i=1}^{N} -y_{i} log( 1 + e^{ -w^T x_i } ) + ( 1 - y_{i} )
# ( -w^T x_i - log( 1 + e^{ -w^T x_i } ) ) \nonumber \\
# &= \sum_{i=1}^{N} ( y_{i} - 1 ) ( w^T x_i ) - log( 1 + e^{ -w^T x_i } ) \nonumber
# \end{align}
# $$

# %% [markdown]
# ### <b><u>Gradient Descent on Logistic Cost Function

# %% [markdown]
# Now that we obtain the formula to assess our algorithm, we'll dive into the meat of the algorithm, which is to derive the gradient for the formula (the derivative of the formula with respect to each coefficient):
#
# #### $$\ell(w) = \sum_{i=1}^{N} ( y_{i} - 1 ) ( w^T x_i ) - log( 1 + e^{ -w^T x_i } )$$
#
# And it turns out the derivative of log likelihood with respect to to a single coefficient $w_j$ is as follows (the form is the same for all coefficients):
#
# #### $$
# \frac{\partial\ell(w)}{\partial w_j} = \sum_{i=1}^N (x_{ij})\left( y_i - \frac{1}{ 1 + e^{-w^Tx_i} } \right )
# $$
#
# To compute it, you simply need the following two terms:
#
# -  $\left( y_i - \frac{1}{ 1 + e^{-w^Tx_i} } \right )$ is the vector containing the difference between the predicted probability and the original label.
# -  $x_{ij}$ is the vector containing the $j_{th}$ feature's value.

# %% [markdown]
# #### <b>Updating model parameters using Gradient Descent

# %% [markdown]
# Recall our task is to find the optimal value for each individual weight to lower the cost. This requires taking the partial derivative of the cost/error function with respect to a single weight, and then running gradient descent for each individual weight to update them. Thus, for any individual weight $w_j$, we'll compute the following:
#
# #### $$ w_j^{(t + 1)} = w_j^{(t)} + \alpha * \sum_{s = i}^{i+B} \frac{\partial\ell_s(w)}{\partial w_j}$$
#
# where:
#
# -  $\alpha$ denotes the the learning rate or so called step size, in other places you'll see it denoted as $\eta$.
# - $w_j^{(t)}$ denotes the weight of the $j_{th}$ feature at iteration $t$.
#
# And we'll do this iteratively for each weight, many times, until the whole network's cost function is minimized.

# %% [markdown]
# ##🤖🌲**Mnemonic**🕵️‍♂️🦉

# %% [markdown]
# 📖 Once upon a time, in a world where robots ruled the land, two friends, Alice and Bob, set out on an adventure to explore the vast and mysterious machine learning forest.
#
# 🐍 Armed with their trusty Python libraries for machine learning, including NumPy, Pandas, Scikit-Learn, and TensorFlow, they journeyed deep into the heart of the forest, eager to put their skills to the test.
#
# 🔍 As they wandered through the forest, they encountered a range of challenges, from data with missing values to features that needed scaling. But with their mastery of critical data preprocessing techniques, such as feature scaling, one-hot encoding, and handling missing data, they were able to overcome each obstacle they faced.
#
# 🏗️ Finally, they came to a clearing in the forest, where they discovered an ancient and mysterious machine learning model, long forgotten by the robots that once roamed these lands.
#
# 🤖 With their knowledge of Scikit-Learn, Alice and Bob were able to load the data, split it into training and test sets, and fit the model to the data with ease. They evaluated its performance using various metrics, and before long, they had revived the ancient model, unleashing its power once again.
#
# 🚀 And with that, Alice and Bob emerged from the machine learning forest, their skills honed, their knowledge expanded, and their confidence soaring. They knew that no machine learning challenge would be too great for them, for they had mastered the art of supervised algorithm implementation!

# %% [markdown]
# ## **Additional Resources:**

# %% [markdown]
# **Feature Scaling in Machine Learning** - https://vitalflux.com/python-improve-model-performance-using-feature-scaling/
#
# **Train-Test Split for Evaluating Machine Learning Algorithms** - https://machinelearningmastery.com/train-test-split-for-evaluating-machine-learning-algorithms/
#
# **What is Model Tuning?** - https://domino.ai/data-science-dictionary/model-tuning

# %% [markdown]
# # **Try it Yourself:**

# %% [markdown]
# ### **Task 1: Working on assignment**

# %% [markdown]
# ####**Problem Statement** :  *Titanic: Predicting Survival using Supervised Learning*
#
# Welcome aboard, aspiring data scientists! You have been chosen to embark on a captivating voyage, delving into the Titanic dataset - a historical record of passengers aboard the ill-fated RMS Titanic. Your mission is to build a predictive model that can determine the survival outcome of passengers based on various features.
# The Titanic dataset contains a mix of categorical and numerical attributes, offering you a real-world challenge in implementing supervised learning algorithms. Your task is to:
#
# - Load and explore the Titanic dataset, gaining insights into its structure and contents. Analyze the distribution of features, identify missing data, and understand the relationships between various attributes.
#
# - Preprocess the data, applying one-hot encoding to categorical features and handling missing values for numerical features. Ensure the dataset is ready for model training.
#
# - Split the data into training and testing sets, where 80% will be used for training and 20% for evaluation.
#
# - Choose appropriate supervised learning algorithms, such as Logistic Regression, Decision Trees, or Random Forests, to build a predictive model. Train the model using the training data.
#
# - Evaluate the performance of your model using suitable evaluation metrics, such as accuracy, precision, recall, and F1-score, on the testing set.
#
# - Fine-tune your model to achieve the highest possible accuracy. Utilize techniques like Grid Search or Randomized Search for hyperparameter tuning.
#
# - Use the trained model to predict the survival outcome of new passengers with known features. Visualize the predictions and discuss insights obtained from the model.

# %% [markdown]
# ### **Task 2: Community Engagement**
#
# Write the answers for the following questions:
#
# i) What are the data processing techniques you used while handling missing values, feature encoding and scaling?
#
# ii) Which evaluation metric you used to evaluate the performance of your model and why?
#
# iii) Which hyperparameter tuning method you used and why?
#
# Share the answers on the AlmaBetter Community Platform within your Cohort group.
#
# Your expedition will not only hone your data science skills but also provide valuable insights into the fate of passengers aboard the Titanic. So, set sail on this thrilling journey, and let your data-driven analysis illuminate the secrets hidden within the Titanic dataset!
#
# Bon voyage and happy data exploration! 🚢🌊
